# %% [markdown]
# ### Importing libraries

# %%
# Numerical python library
import numpy as np
# Python DataFrame library
import pandas as pd
# Python Visualisation library
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
#Ignoring warnings
import warnings
warnings.filterwarnings('ignore')
# Stratified Sample split
from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit
from sklearn.impute import SimpleImputer
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.linear_model import  LinearRegression
from sklearn.cluster import KMeans

from sklearn.metrics import roc_auc_score, roc_curve

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

from sklearn.preprocessing import PolynomialFeatures

from imblearn.over_sampling import SMOTE

# %%
seed = 47
np.random.seed(47)

# %% [markdown]
# ### Importing the datasets

# %%
#Train dataset
train = pd.read_csv('train.csv', index_col = 'id')
#Test dataset
test = pd.read_csv('test.csv', index_col = 'id') 
#Sample Submission dataset
sample_sub = pd.read_csv('sample_submission.csv')##Sample Submission dataset

# %% [markdown]
# ### Splitting Dataset

# %%
X = train.drop('song_popularity', axis = 1).copy()
y = train['song_popularity'].copy()


X['song_duration_ms'] =  X['song_duration_ms']/60000
X['tempo'] =  X['tempo']/100
X['NUll_count'] = train.isnull().sum(axis = 1)

test['song_duration_ms'] =  test['song_duration_ms']/60000
test['tempo'] =  test['tempo']/100
test['NUll_count'] = test.isnull().sum(axis = 1)

# %% [raw]
# split = StratifiedShuffleSplit(n_splits = 1, test_size = 0.25, random_state = seed)
# for train_index, test_index in split.split(X, y):
#     X_train_ = X.iloc[train_index]; y_train_ = y.iloc[train_index]
#     X_HoldOut = X.iloc[test_index]; y_HoldOut = y.iloc[test_index]

# %% [markdown]
# ### Filling Missing values

# %%
columns = test.columns

# %%
it_imputer = IterativeImputer(max_iter = 50, random_state = seed)

X_it = pd.DataFrame(it_imputer.fit_transform(X), columns = columns)
                            
test_it = pd.DataFrame(it_imputer.transform(test), columns = columns)

# %% [markdown]
# ### Feature Binning

# %%
bin_col = ['energy','liveness','acousticness']
for col in bin_col:
    X_it[f'{col}_bin'] = pd.cut(X_it[col],5, labels=['A','B','C','D','E'])
    test_it[f'{col}_bin'] = pd.cut(test_it[col],5, labels=['A','B','C','D','E'])
    
X_it = pd.get_dummies(X_it, drop_first= True)
test_it = pd.get_dummies(test_it, drop_first= True)

# %% [markdown]
# ### Clustering

# %%
Cluster_1 = ['instrumentalness', 'key', 'liveness','loudness', 'audio_mode']
Cluster_2 = ['song_duration_ms', 'acousticness', 'danceability']
Cluster_3 = ['acousticness', 'danceability', 'energy']
Cluster_4 = ['speechiness', 'tempo', 'time_signature', 'audio_valence']

cluster = KMeans(n_clusters=5, random_state= 2022)

for (clus_name, clus) in [('Cluster_1',Cluster_1),('Cluster_2',Cluster_2),('Cluster_3',Cluster_3),('Cluster_4',Cluster_4)]:
    X_it[clus_name] = cluster.fit_predict(X_it[clus])
    test_it[clus_name] = cluster.fit_predict(test_it[clus])

# %% [markdown]
# ### Feature Interaction

# %% [raw]
# poly_columns = ['acousticness','energy','instrumentalness','liveness','song_duration_ms','loudness','tempo']#'speechiness','danceability','audio_valence'
# #'acousticness','energy','instrumentalness','liveness','song_duration_ms','loudness','tempo'
#
# poly = PolynomialFeatures(degree = 2, interaction_only = True, include_bias = False)
#
# col_name = ['feat_1','feat_2','feat_3','feat_4','feat_5','feat_6','feat_7','feat_8','feat_9','feat_10',
# 'feat_11','feat_12','feat_13','feat_14','feat_15','feat_16','feat_17','feat_18','feat_19','feat_20',
# 'feat_21','feat_22','feat_23','feat_24','feat_25','feat_26','feat_27','feat_28']
#
# poly_feat_train = pd.DataFrame(poly.fit_transform(X_it[poly_columns]), columns = col_name)
# poly_feat_test = pd.DataFrame(poly.fit_transform(test_it[poly_columns]), columns = col_name)
#
# X_it = pd.concat([X_it, poly_feat_train], axis =1)
# test_it = pd.concat([test_it, poly_feat_test], axis =1)

# %% [markdown]
# ### SMOTE

# %% [raw]
# sm = SMOTE(sampling_strategy = {1:22000,0:26000}, random_state = 2022)
#
# X_it, y = sm.fit_resample(X_it, y)

# %% [markdown]
# ### Data Transformation

# %% [raw]
# log_transformation = ['speechiness','liveness', 'instrumentalness']
# no_transformation = ['acousticness', 'danceability', 'energy','tempo','loudness', 'audio valence', 'danceability']
#
# X_it[['speechiness','liveness']] = np.log10(X_it[['speechiness','liveness']])
# #X_it['instrumentalness'] = np.log10(X_it['instrumentalness'] + 1)
#
# test_it[['speechiness','liveness']] = np.log10(test_it[['speechiness','liveness']])
# #test_it['instrumentalness'] = np.log10(test_it['instrumentalness'] + 1)

# %% [markdown]
# imputer = SimpleImputer(missing_values = np.nan, strategy = "median", add_indicator= True)
# X_filled = pd.DataFrame(imputer.fit_transform(X_train_))

# %% [markdown]
# ### CROSS VALIDATION FUNCTION

# %% [raw]
# skfold = StratifiedKFold(n_splits = 10, random_state = seed, shuffle = True)
# def lgb_predict(X,y):
#     train_roc, val_roc = [], []
#     train_pred_df = np.zeros(len(train))
#     val_pred_df = np.zeros(len(train))
#
#     for train_index, val_index in skfold.split(X, y):
#         X_train = X.iloc[train_index] ; y_train = y.iloc[train_index].values
#         X_val = X.iloc[val_index] ; y_val = y.iloc[val_index].values
#
#         model_LGBM.fit(X_train, y_train, early_stopping_rounds = 200, eval_metric="auc",
#                            eval_set=[(X_val, y_val)], verbose = 0)
#
#         train_pred = model_LGBM.predict_proba(X_train)[:,1]
#         val_pred = model_LGBM.predict_proba(X_val)[:,1]
#
#         train_pred_df[train_index] = train_pred
#         val_pred_df[val_index] = val_pred
#
#         train_roc.append(roc_auc_score(y_train, train_pred)); val_roc.append(roc_auc_score(y_val,val_pred))
#
#     print(f'Training ROC score : {np.mean(train_roc)}')
#     print(f'Testing ROC score : {np.mean(val_roc)} +/- {np.std(val_roc)}')

# %% [markdown]
# ### SEARCHING FOR THE BEST FEATURE INTERACTIONS

# %% [raw]
# for col in col_name:
#     #Train df
#     train_df = X_it.copy()
#     train_df[col] = poly_feat_train[col]
#     y_new = y.copy()
#     print(f'*******************{col}****************************')
#     lgb_predict(X = train_df, y = y_new)
#     print('\n')

# %% [markdown]
# # Trying different Models

# %%
scale_pos_weight = len(train['song_popularity'][train['song_popularity'].eq(0)])/ len(train['song_popularity'][train['song_popularity'].eq(1)])
skfold = StratifiedKFold(n_splits = 10, random_state = seed, shuffle = True)

# %% [markdown]
# ### LGBM1

# %%
model_LGBM1 = LGBMClassifier(n_estimators=1000,learning_rate=0.01,subsample_freq=5,
                            colsample_bytree=0.8,min_child_samples=10,random_state=465,
                            subsample=0.7,num_leaves=100,metric='auc',
                           max_depth=7,scale_pos_weight= scale_pos_weight, use_missing = True)

train_roc_lgbm1, val_roc_lgbm1 = [], []

train_pred_lgbm1 = np.zeros(len(X_it))
val_pred_lgbm1 = np.zeros(len(X_it))
test_pred_lgbm1 = np.zeros(len(test))
fold = 0


for train_index, val_index in skfold.split(X_it, y):
    X_train = X_it.iloc[train_index] ; y_train = y.iloc[train_index].values
    X_val = X_it.iloc[val_index] ; y_val = y.iloc[val_index].values
    fold += 1
    print(f'***************************Fold :{fold}***********************************************')
    
    model_LGBM1.fit(X_train, y_train, early_stopping_rounds = 200, eval_metric="auc",
                       eval_set=[(X_val, y_val)],verbose=100)
    
    train_pred = model_LGBM1.predict_proba(X_train)[:,1]
    val_pred = model_LGBM1.predict_proba(X_val)[:,1]

    train_pred_lgbm1[train_index] = train_pred
    val_pred_lgbm1[val_index] = val_pred
    
    test_pred_lgbm1 += model_LGBM1.predict_proba(test_it)[:,1]
    
    print(f'Train score : {roc_auc_score(y_train, train_pred)}')
    print(f'Validation score : {roc_auc_score(y_val, val_pred)}\n')
    
   
    train_roc_lgbm1.append(roc_auc_score(y_train, train_pred)); val_roc_lgbm1.append(roc_auc_score(y_val,val_pred))
    
test_pred_lgbm1 = test_pred_lgbm1 / 10
print(f'Training ROC score : {np.mean(train_roc_lgbm1)}')
print(f'Testing ROC score : {np.mean(val_roc_lgbm1)} +/- {np.std(val_roc_lgbm1)}')
# Out:
# ***************************Fold :1***********************************************
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's auc: 0.566752
# [200]	valid_0's auc: 0.568751
# [300]	valid_0's auc: 0.570987
# [400]	valid_0's auc: 0.572315
# [500]	valid_0's auc: 0.570888
# [600]	valid_0's auc: 0.569415
# Early stopping, best iteration is:
# [403]	valid_0's auc: 0.572522
# Train score : 0.7820554804878882
# Validation score : 0.572522415415728
#
# ***************************Fold :2***********************************************
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's auc: 0.570091
# [200]	valid_0's auc: 0.577319
# [300]	valid_0's auc: 0.576774
# [400]	valid_0's auc: 0.57496
# Early stopping, best iteration is:
# [262]	valid_0's auc: 0.57863
# Train score : 0.7509601763784859
# Validation score : 0.5786303985991395
#
# ***************************Fold :3***********************************************
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's auc: 0.56875
# [200]	valid_0's auc: 0.572474
# [300]	valid_0's auc: 0.570339
# Early stopping, best iteration is:
# [181]	valid_0's auc: 0.57283
# Train score : 0.7295862476126868
# Validation score : 0.5728298252891718
#
# ***************************Fold :4***********************************************
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's auc: 0.566443
# [200]	valid_0's auc: 0.565559
# Early stopping, best iteration is:
# [55]	valid_0's auc: 0.570372
# Train score : 0.6870453537734594
# Validation score : 0.570371625879755
#
# ***************************Fold :5***********************************************
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's auc: 0.593816
# [200]	valid_0's auc: 0.592615
# [300]	valid_0's auc: 0.592399
# Early stopping, best iteration is:
# [133]	valid_0's auc: 0.595331
# Train score : 0.7175307778617861
# Validation score : 0.5953309503226454
#
# ***************************Fold :6***********************************************
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's auc: 0.553278
# [200]	valid_0's auc: 0.55174
# Early stopping, best iteration is:
# [89]	valid_0's auc: 0.553887
# Train score : 0.6994694663630143
# Validation score : 0.5538872861846897
#
# ***************************Fold :7***********************************************
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's auc: 0.570025
# [200]	valid_0's auc: 0.5745
# [300]	valid_0's auc: 0.576986
# [400]	valid_0's auc: 0.576431
# [500]	valid_0's auc: 0.577697
# [600]	valid_0's auc: 0.576529
# Early stopping, best iteration is:
# [455]	valid_0's auc: 0.5789
# Train score : 0.7922904385770764
# Validation score : 0.5788999944957635
#
# ***************************Fold :8***********************************************
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's auc: 0.568947
# [200]	valid_0's auc: 0.573218
# [300]	valid_0's auc: 0.575369
# [400]	valid_0's auc: 0.575065
# [500]	valid_0's auc: 0.574954
# Early stopping, best iteration is:
# [327]	valid_0's auc: 0.576604
# Train score : 0.765624283938069
# Validation score : 0.576604404036872
#
# ***************************Fold :9***********************************************
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's auc: 0.57564
# [200]	valid_0's auc: 0.573637
# [300]	valid_0's auc: 0.572956
# Early stopping, best iteration is:
# [134]	valid_0's auc: 0.577396
# Train score : 0.7157004044654267
# Validation score : 0.5773963125931538
#
# ***************************Fold :10***********************************************
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's auc: 0.582539
# [200]	valid_0's auc: 0.583355
# [300]	valid_0's auc: 0.582149
# Early stopping, best iteration is:
# [150]	valid_0's auc: 0.58375
# Train score : 0.7223764187129528
# Validation score : 0.5837496586833649
#
# Training ROC score : 0.7362639048170846
# Testing ROC score : 0.5760222871500285 +/- 0.00997083823272282

# %% [markdown]
# ### LGBM 2

# %%
model_LGBM2 = LGBMClassifier(n_estimators= 200,learning_rate=0.05,subsample_freq=5,
                            colsample_bytree=0.5,min_child_samples=20,random_state=2022,tree_learner = 'serial',
                            subsample=0.7,num_leaves=20,metric='auc',
                           max_depth=7,scale_pos_weight= scale_pos_weight, use_missing = True, reg_alpha = 0.08, lambda_l1 = 1.04, lambda_l2 = 1)

train_roc_lgbm2, val_roc_lgbm2 = [], []

train_pred_lgbm2 = np.zeros(len(X_it))
val_pred_lgbm2 = np.zeros(len(X_it))
test_pred_lgbm2 = np.zeros(len(test))
fold = 0


for train_index, val_index in skfold.split(X_it, y):
    X_train = X_it.iloc[train_index] ; y_train = y.iloc[train_index].values
    X_val = X_it.iloc[val_index] ; y_val = y.iloc[val_index].values
    fold += 1
    print(f'***************************Fold :{fold}***********************************************')
    
    model_LGBM2.fit(X_train, y_train, early_stopping_rounds = 200, eval_metric="auc",
                       eval_set=[(X_val, y_val)],verbose=100)
    
    train_pred = model_LGBM2.predict_proba(X_train)[:,1]
    val_pred = model_LGBM2.predict_proba(X_val)[:,1]

    train_pred_lgbm2[train_index] = train_pred
    val_pred_lgbm2[val_index] = val_pred
    
    test_pred_lgbm2 += model_LGBM2.predict_proba(test_it)[:,1]
    
    print(f'Train score : {roc_auc_score(y_train, train_pred)}')
    print(f'Validation score : {roc_auc_score(y_val, val_pred)}\n')
    
   
    train_roc_lgbm2.append(roc_auc_score(y_train, train_pred)); val_roc_lgbm2.append(roc_auc_score(y_val,val_pred))
    
test_pred_lgbm2 = test_pred_lgbm2 / 10
print(f'Training ROC score : {np.mean(train_roc_lgbm2)}')
print(f'Testing ROC score : {np.mean(val_roc_lgbm2)} +/- {np.std(val_roc_lgbm2)}')
# Out:
# ***************************Fold :1***********************************************
# [LightGBM] [Warning] lambda_l1 is set=1.04, reg_alpha=0.08 will be ignored. Current value: lambda_l1=1.04
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's auc: 0.570381
# [200]	valid_0's auc: 0.569246
# Did not meet early stopping. Best iteration is:
# [90]	valid_0's auc: 0.571446
# Train score : 0.6462731365931154
# Validation score : 0.5714458061223416
#
# ***************************Fold :2***********************************************
# [LightGBM] [Warning] lambda_l1 is set=1.04, reg_alpha=0.08 will be ignored. Current value: lambda_l1=1.04
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's auc: 0.576545
# [200]	valid_0's auc: 0.572959
# Did not meet early stopping. Best iteration is:
# [57]	valid_0's auc: 0.57978
# Train score : 0.6314944288370924
# Validation score : 0.5797804192055871
#
# ***************************Fold :3***********************************************
# [LightGBM] [Warning] lambda_l1 is set=1.04, reg_alpha=0.08 will be ignored. Current value: lambda_l1=1.04
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's auc: 0.573925
# [200]	valid_0's auc: 0.572034
# Did not meet early stopping. Best iteration is:
# [88]	valid_0's auc: 0.574759
# Train score : 0.64583216505976
# Validation score : 0.5747587615187613
#
# ***************************Fold :4***********************************************
# [LightGBM] [Warning] lambda_l1 is set=1.04, reg_alpha=0.08 will be ignored. Current value: lambda_l1=1.04
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's auc: 0.567131
# [200]	valid_0's auc: 0.566281
# Did not meet early stopping. Best iteration is:
# [164]	valid_0's auc: 0.568279
# Train score : 0.6771007409427112
# Validation score : 0.5682785937739109
#
# ***************************Fold :5***********************************************
# [LightGBM] [Warning] lambda_l1 is set=1.04, reg_alpha=0.08 will be ignored. Current value: lambda_l1=1.04
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's auc: 0.586768
# [200]	valid_0's auc: 0.585795
# Did not meet early stopping. Best iteration is:
# [115]	valid_0's auc: 0.588038
# Train score : 0.6566952022919472
# Validation score : 0.5880375669547218
#
# ***************************Fold :6***********************************************
# [LightGBM] [Warning] lambda_l1 is set=1.04, reg_alpha=0.08 will be ignored. Current value: lambda_l1=1.04
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's auc: 0.556544
# [200]	valid_0's auc: 0.556467
# Did not meet early stopping. Best iteration is:
# [26]	valid_0's auc: 0.559576
# Train score : 0.6154952566991614
# Validation score : 0.5595762115526373
#
# ***************************Fold :7***********************************************
# [LightGBM] [Warning] lambda_l1 is set=1.04, reg_alpha=0.08 will be ignored. Current value: lambda_l1=1.04
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's auc: 0.57564
# [200]	valid_0's auc: 0.576763
# Did not meet early stopping. Best iteration is:
# [200]	valid_0's auc: 0.576763
# Train score : 0.6903820403742094
# Validation score : 0.57676305556365
#
# ***************************Fold :8***********************************************
# [LightGBM] [Warning] lambda_l1 is set=1.04, reg_alpha=0.08 will be ignored. Current value: lambda_l1=1.04
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's auc: 0.574155
# [200]	valid_0's auc: 0.574371
# Did not meet early stopping. Best iteration is:
# [48]	valid_0's auc: 0.577698
# Train score : 0.6267279834114232
# Validation score : 0.5776979663464497
#
# ***************************Fold :9***********************************************
# [LightGBM] [Warning] lambda_l1 is set=1.04, reg_alpha=0.08 will be ignored. Current value: lambda_l1=1.04
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's auc: 0.578014
# [200]	valid_0's auc: 0.577656
# Did not meet early stopping. Best iteration is:
# [56]	valid_0's auc: 0.580958
# Train score : 0.6282587443359189
# Validation score : 0.5809581472955311
#
# ***************************Fold :10***********************************************
# [LightGBM] [Warning] lambda_l1 is set=1.04, reg_alpha=0.08 will be ignored. Current value: lambda_l1=1.04
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's auc: 0.583404
# [200]	valid_0's auc: 0.583469
# Did not meet early stopping. Best iteration is:
# [145]	valid_0's auc: 0.584411
# Train score : 0.6677839370495685
# Validation score : 0.5844107067116071
#
# Training ROC score : 0.6486043635594908
# Testing ROC score : 0.5761707235045197 +/- 0.007805984715740842

# %% [markdown]
# ### XGBOOST

# %%
model_xgb = XGBClassifier(learning_rate=0.01,subsample=0.7,colsample_bytree=0.9,reg_alpha=10,
               n_jobs=-1,n_estimators=1500,max_depth= 5,random_state=34)

train_roc_xgb, val_roc_xgb = [], []

train_pred_xgb = np.zeros(len(X_it))
val_pred_xgb = np.zeros(len(X_it))
test_pred_xgb = np.zeros(len(test))
fold = 0

for train_index, val_index in skfold.split(X_it, y):
    X_train = X_it.iloc[train_index] ; y_train = y.iloc[train_index].values
    X_val = X_it.iloc[val_index] ; y_val = y.iloc[val_index].values
    fold += 1
    print(f'***************************Fold :{fold}***********************************************')
    
    model_xgb.fit(X_train, y_train, early_stopping_rounds = 200, eval_metric="auc",
                       eval_set=[(X_val, y_val)],verbose=250)
    
    train_pred = model_xgb.predict_proba(X_train, ntree_limit = model_xgb.get_booster().best_ntree_limit)[:,1]
    val_pred = model_xgb.predict_proba(X_val, ntree_limit = model_xgb.get_booster().best_ntree_limit)[:,1]

    train_pred_xgb[train_index] = train_pred
    val_pred_xgb[val_index] = val_pred
    
    test_pred_xgb += model_xgb.predict_proba(test_it)[:,1]
    
    print(f'Train score : {roc_auc_score(y_train, train_pred)}')
    print(f'Validation score : {roc_auc_score(y_val, val_pred)}\n')
    
   
    train_roc_xgb.append(roc_auc_score(y_train, train_pred)); val_roc_xgb.append(roc_auc_score(y_val,val_pred))
    
test_pred_xgb = test_pred_xgb / 10
print(f'Training ROC score : {np.mean(train_roc_xgb)}')
print(f'Testing ROC score : {np.mean(val_roc_xgb)} +/- {np.std(val_roc_xgb)}')
# Out:
# ***************************Fold :1***********************************************
# [0]	validation_0-auc:0.53648
# [250]	validation_0-auc:0.56496
# [500]	validation_0-auc:0.57039
# [750]	validation_0-auc:0.57123
# [1000]	validation_0-auc:0.57140
# [1250]	validation_0-auc:0.57081
# [1375]	validation_0-auc:0.57007
# Train score : 0.696283459042818
# Validation score : 0.5715710371857989
#
# ***************************Fold :2***********************************************
# [0]	validation_0-auc:0.53401
# [250]	validation_0-auc:0.57864
# [500]	validation_0-auc:0.58032
# [634]	validation_0-auc:0.58000
# Train score : 0.6434232203478575
# Validation score : 0.5807882053929786
#
# ***************************Fold :3***********************************************
# [0]	validation_0-auc:0.53621
# [250]	validation_0-auc:0.56966
# [500]	validation_0-auc:0.57236
# [746]	validation_0-auc:0.57231
# Train score : 0.6505152285091139
# Validation score : 0.5727426493549116
#
# ***************************Fold :4***********************************************
# [0]	validation_0-auc:0.53140
# [250]	validation_0-auc:0.56968
# [488]	validation_0-auc:0.56990
# Train score : 0.6296425309566638
# Validation score : 0.5711020954341672
#
# ***************************Fold :5***********************************************
# [0]	validation_0-auc:0.54876
# [250]	validation_0-auc:0.58205
# [500]	validation_0-auc:0.58789
# [750]	validation_0-auc:0.58999
# [1000]	validation_0-auc:0.59085
# [1221]	validation_0-auc:0.58989
# Train score : 0.6851569146008358
# Validation score : 0.5911055043445694
#
# ***************************Fold :6***********************************************
# [0]	validation_0-auc:0.54125
# [250]	validation_0-auc:0.56007
# [500]	validation_0-auc:0.56223
# [674]	validation_0-auc:0.56134
# Train score : 0.6463097115611426
# Validation score : 0.5624907588183807
#
# ***************************Fold :7***********************************************
# [0]	validation_0-auc:0.54252
# [250]	validation_0-auc:0.57125
# [500]	validation_0-auc:0.57608
# [750]	validation_0-auc:0.57631
# [840]	validation_0-auc:0.57579
# Train score : 0.6580017340134067
# Validation score : 0.5770687565497719
#
# ***************************Fold :8***********************************************
# [0]	validation_0-auc:0.53884
# [250]	validation_0-auc:0.57124
# [500]	validation_0-auc:0.57529
# [750]	validation_0-auc:0.57493
# [767]	validation_0-auc:0.57482
# Train score : 0.6523521282265088
# Validation score : 0.5756140461643565
#
# ***************************Fold :9***********************************************
# [0]	validation_0-auc:0.56145
# [250]	validation_0-auc:0.58027
# [500]	validation_0-auc:0.58113
# [571]	validation_0-auc:0.58106
# Train score : 0.6359394124204761
# Validation score : 0.5814216903618658
#
# ***************************Fold :10***********************************************
# [0]	validation_0-auc:0.55858
# [250]	validation_0-auc:0.58000
# [500]	validation_0-auc:0.58485
# [750]	validation_0-auc:0.58539
# [854]	validation_0-auc:0.58556
# Train score : 0.6601184755468502
# Validation score : 0.5858356024818712
#
# Training ROC score : 0.6557742815225673
# Testing ROC score : 0.5769740346088672 +/- 0.007783031883254162

# %% [markdown]
# ### CATBOOST

# %%
model_catboost =  CatBoostClassifier(random_seed=34,bootstrap_type='Bayesian',max_depth=6,learning_rate=0.007,
                          iterations=8000,silent=True,eval_metric='AUC')

train_roc_cat, val_roc_cat = [], []

train_pred_cat = np.zeros(len(X_it))
val_pred_cat = np.zeros(len(X_it))
test_pred_cat = np.zeros(len(test))
fold = 0

for train_index, val_index in skfold.split(X_it, y):
    X_train = X_it.iloc[train_index] ; y_train = y.iloc[train_index].values
    X_val = X_it.iloc[val_index] ; y_val = y.iloc[val_index].values
    fold += 1
    print(f'***************************Fold :{fold}***********************************************')
    
    model_catboost.fit(X_train, y_train, early_stopping_rounds = 200,
                       eval_set=[(X_val, y_val)],verbose=250,use_best_model=True)
    
    train_pred = model_catboost.predict_proba(X_train)[:,1]
    val_pred = model_catboost.predict_proba(X_val)[:,1]

    train_pred_cat[train_index] = train_pred
    val_pred_cat[val_index] = val_pred
    
    test_pred_cat += model_catboost.predict_proba(test_it)[:,1]
    
    print(f'Train score : {roc_auc_score(y_train, train_pred)}')
    print(f'Validation score : {roc_auc_score(y_val, val_pred)}\n')
    
   
    train_roc_cat.append(roc_auc_score(y_train, train_pred)); val_roc_cat.append(roc_auc_score(y_val,val_pred))
    
test_pred_cat = test_pred_cat / 10
print(f'Training ROC score : {np.mean(train_roc_cat)}')
print(f'Testing ROC score : {np.mean(val_roc_cat)} +/- {np.std(val_roc_cat)}')
# Out:
# ***************************Fold :1***********************************************
# 0:	test: 0.5257092	best: 0.5257092 (0)	total: 101ms	remaining: 13m 28s
# 250:	test: 0.5602347	best: 0.5602676 (247)	total: 8.13s	remaining: 4m 11s
# 500:	test: 0.5656277	best: 0.5656401 (499)	total: 16.3s	remaining: 4m 3s
# 750:	test: 0.5683215	best: 0.5683215 (750)	total: 24.4s	remaining: 3m 55s
# 1000:	test: 0.5699201	best: 0.5699368 (999)	total: 32.6s	remaining: 3m 48s
# 1250:	test: 0.5707948	best: 0.5709446 (1205)	total: 40.8s	remaining: 3m 40s
# 1500:	test: 0.5714671	best: 0.5714671 (1500)	total: 49s	remaining: 3m 31s
# 1750:	test: 0.5718212	best: 0.5719851 (1643)	total: 57.1s	remaining: 3m 23s
# 2000:	test: 0.5718177	best: 0.5723294 (1917)	total: 1m 5s	remaining: 3m 15s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.5723294408
# bestIteration = 1917
#
# Shrink model to first 1918 iterations.
# Train score : 0.6768828386617752
# Validation score : 0.572329440824409
#
# ***************************Fold :2***********************************************
# 0:	test: 0.5377086	best: 0.5377086 (0)	total: 61ms	remaining: 8m 8s
# 250:	test: 0.5748573	best: 0.5748573 (250)	total: 8.32s	remaining: 4m 16s
# 500:	test: 0.5779365	best: 0.5779365 (500)	total: 16.5s	remaining: 4m 6s
# 750:	test: 0.5793729	best: 0.5798859 (726)	total: 24.9s	remaining: 4m
# 1000:	test: 0.5798268	best: 0.5802082 (957)	total: 33.1s	remaining: 3m 51s
# 1250:	test: 0.5801666	best: 0.5803777 (1205)	total: 41.3s	remaining: 3m 42s
# 1500:	test: 0.5801917	best: 0.5806802 (1379)	total: 49.5s	remaining: 3m 34s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.5806802476
# bestIteration = 1379
#
# Shrink model to first 1380 iterations.
# Train score : 0.6546110994629384
# Validation score : 0.5806802475796533
#
# ***************************Fold :3***********************************************
# 0:	test: 0.5347445	best: 0.5347445 (0)	total: 49ms	remaining: 6m 32s
# 250:	test: 0.5611283	best: 0.5611283 (250)	total: 8.15s	remaining: 4m 11s
# 500:	test: 0.5661362	best: 0.5661362 (500)	total: 16.4s	remaining: 4m 4s
# 750:	test: 0.5693171	best: 0.5693682 (748)	total: 24.6s	remaining: 3m 57s
# 1000:	test: 0.5708920	best: 0.5709036 (989)	total: 32.8s	remaining: 3m 49s
# 1250:	test: 0.5721332	best: 0.5721332 (1250)	total: 41s	remaining: 3m 41s
# 1500:	test: 0.5727216	best: 0.5728177 (1494)	total: 49.3s	remaining: 3m 33s
# 1750:	test: 0.5733923	best: 0.5733923 (1750)	total: 57.5s	remaining: 3m 25s
# 2000:	test: 0.5735993	best: 0.5736303 (1952)	total: 1m 5s	remaining: 3m 17s
# 2250:	test: 0.5737626	best: 0.5738776 (2153)	total: 1m 13s	remaining: 3m 8s
# 2500:	test: 0.5743342	best: 0.5744300 (2440)	total: 1m 22s	remaining: 3m
# 2750:	test: 0.5749223	best: 0.5751550 (2683)	total: 1m 30s	remaining: 2m 53s
# 3000:	test: 0.5751655	best: 0.5752610 (2895)	total: 1m 39s	remaining: 2m 45s
# 3250:	test: 0.5747663	best: 0.5753436 (3147)	total: 1m 47s	remaining: 2m 36s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.575343623
# bestIteration = 3147
#
# Shrink model to first 3148 iterations.
# Train score : 0.7216509620549442
# Validation score : 0.575343622972451
#
# ***************************Fold :4***********************************************
# 0:	test: 0.5432949	best: 0.5432949 (0)	total: 69.4ms	remaining: 9m 15s
# 250:	test: 0.5734117	best: 0.5734946 (249)	total: 9.37s	remaining: 4m 49s
# 500:	test: 0.5744578	best: 0.5746508 (479)	total: 17.6s	remaining: 4m 22s
# 750:	test: 0.5747617	best: 0.5751463 (680)	total: 25.7s	remaining: 4m 8s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.5751463301
# bestIteration = 680
#
# Shrink model to first 681 iterations.
# Train score : 0.6235894055417298
# Validation score : 0.575146330068599
#
# ***************************Fold :5***********************************************
# 0:	test: 0.5380045	best: 0.5380045 (0)	total: 43.3ms	remaining: 5m 46s
# 250:	test: 0.5823771	best: 0.5827430 (244)	total: 8.14s	remaining: 4m 11s
# 500:	test: 0.5860166	best: 0.5860401 (499)	total: 16.3s	remaining: 4m 4s
# 750:	test: 0.5883368	best: 0.5883651 (749)	total: 24.6s	remaining: 3m 57s
# 1000:	test: 0.5898480	best: 0.5898480 (1000)	total: 35.3s	remaining: 4m 7s
# 1250:	test: 0.5901524	best: 0.5903634 (1138)	total: 44.9s	remaining: 4m 2s
# 1500:	test: 0.5910992	best: 0.5911833 (1498)	total: 53.3s	remaining: 3m 50s
# 1750:	test: 0.5916186	best: 0.5916466 (1744)	total: 1m 1s	remaining: 3m 39s
# 2000:	test: 0.5915379	best: 0.5918037 (1862)	total: 1m 10s	remaining: 3m 30s
# 2250:	test: 0.5915435	best: 0.5919963 (2061)	total: 1m 18s	remaining: 3m 20s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.5919963003
# bestIteration = 2061
#
# Shrink model to first 2062 iterations.
# Train score : 0.6816217099763133
# Validation score : 0.591996300289566
#
# ***************************Fold :6***********************************************
# 0:	test: 0.5180335	best: 0.5180335 (0)	total: 56.9ms	remaining: 7m 35s
# 250:	test: 0.5559209	best: 0.5562498 (248)	total: 8.25s	remaining: 4m 14s
# 500:	test: 0.5573587	best: 0.5573970 (496)	total: 16.7s	remaining: 4m 9s
# 750:	test: 0.5578754	best: 0.5578754 (750)	total: 25.1s	remaining: 4m 2s
# 1000:	test: 0.5581652	best: 0.5583258 (932)	total: 33.9s	remaining: 3m 56s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.5583257515
# bestIteration = 932
#
# Shrink model to first 933 iterations.
# Train score : 0.6363390611802515
# Validation score : 0.5583257515171727
#
# ***************************Fold :7***********************************************
# 0:	test: 0.5404978	best: 0.5404978 (0)	total: 56.2ms	remaining: 7m 29s
# 250:	test: 0.5698280	best: 0.5698280 (250)	total: 8.91s	remaining: 4m 34s
# 500:	test: 0.5736596	best: 0.5736596 (500)	total: 17.7s	remaining: 4m 25s
# 750:	test: 0.5764895	best: 0.5764895 (750)	total: 26.6s	remaining: 4m 17s
# 1000:	test: 0.5776988	best: 0.5778002 (995)	total: 35.6s	remaining: 4m 8s
# 1250:	test: 0.5783150	best: 0.5784856 (1229)	total: 44.5s	remaining: 4m
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.5785705497
# bestIteration = 1287
#
# Shrink model to first 1288 iterations.
# Train score : 0.6502223955514547
# Validation score : 0.5785705497437292
#
# ***************************Fold :8***********************************************
# 0:	test: 0.5285110	best: 0.5285110 (0)	total: 49.9ms	remaining: 6m 39s
# 250:	test: 0.5777840	best: 0.5784923 (185)	total: 8.93s	remaining: 4m 35s
# 500:	test: 0.5774290	best: 0.5786310 (352)	total: 18.1s	remaining: 4m 31s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.5786309884
# bestIteration = 352
#
# Shrink model to first 353 iterations.
# Train score : 0.6087417286955505
# Validation score : 0.5786309884205971
#
# ***************************Fold :9***********************************************
# 0:	test: 0.5450646	best: 0.5450646 (0)	total: 43.6ms	remaining: 5m 48s
# 250:	test: 0.5698312	best: 0.5700406 (245)	total: 8.86s	remaining: 4m 33s
# 500:	test: 0.5749750	best: 0.5751315 (495)	total: 17.7s	remaining: 4m 24s
# 750:	test: 0.5757337	best: 0.5758708 (738)	total: 26.5s	remaining: 4m 16s
# 1000:	test: 0.5762822	best: 0.5763251 (994)	total: 35.3s	remaining: 4m 6s
# 1250:	test: 0.5764474	best: 0.5765491 (1150)	total: 45.2s	remaining: 4m 3s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.5765490919
# bestIteration = 1150
#
# Shrink model to first 1151 iterations.
# Train score : 0.6462160967184046
# Validation score : 0.576549091854917
#
# ***************************Fold :10***********************************************
# 0:	test: 0.5348720	best: 0.5348720 (0)	total: 45.9ms	remaining: 6m 7s
# 250:	test: 0.5761028	best: 0.5761147 (247)	total: 8.68s	remaining: 4m 27s
# 500:	test: 0.5823142	best: 0.5823758 (467)	total: 17s	remaining: 4m 14s
# 750:	test: 0.5865903	best: 0.5866224 (745)	total: 25.3s	remaining: 4m 3s
# 1000:	test: 0.5878098	best: 0.5878873 (996)	total: 33.5s	remaining: 3m 54s
# 1250:	test: 0.5882040	best: 0.5883017 (1234)	total: 41.9s	remaining: 3m 46s
# 1500:	test: 0.5889776	best: 0.5890809 (1492)	total: 50.3s	remaining: 3m 37s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.5890809436
# bestIteration = 1492
#
# Shrink model to first 1493 iterations.
# Train score : 0.6578837843087905
# Validation score : 0.5890809435772573
#
# Training ROC score : 0.6557759082152153
# Testing ROC score : 0.5776653266848351 +/- 0.00872930278274111

# %% [markdown]
# ### BLENDING

# %%
## TRAIN Sdf
Train_stack = pd.concat([
    pd.DataFrame(train_pred_lgbm1),pd.DataFrame(train_pred_lgbm2),
    pd.DataFrame(train_pred_xgb),pd.DataFrame(train_pred_cat)
],axis = 1)
Train_stack.columns = ['LGBM(1)','LGBM(2)','XGB','CATBOOST']

## TEST STACK
Test_stack = pd.concat([
    pd.DataFrame(test_pred_lgbm1),pd.DataFrame(test_pred_lgbm2),
    pd.DataFrame(test_pred_xgb),pd.DataFrame(test_pred_cat)
],axis = 1)
Test_stack.columns = ['LGBM(1)','LGBM(2)','XGB','CATBOOST']

# %%
weighted_value = (3*Train_stack['LGBM(1)'] + 3*Train_stack['LGBM(2)'] + 5*Train_stack['XGB'] + 7*Train_stack['CATBOOST']) / 18
roc_auc_score(y,weighted_value)
# Out:
# 0.6723150990377728

# %% [markdown]
# ### Submission file

# %%
sample_sub['song_popularity'] = (3*Test_stack['LGBM(1)'] + 3*Test_stack['LGBM(2)'] + 5*Test_stack['XGB'] + 7*Test_stack['CATBOOST']) / 18
sample_sub.to_csv('Blend_1.csv',index= False)
